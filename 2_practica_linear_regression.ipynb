# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Introducción
#
# En esta práctica vamos a trabajar con un dataset sintético. Vamos a implementar una regresión lineal de dos maneras distintas:
#
# 1. Implementando el descenso del gradiente a mano.
# 2. Usando la librería `scikit-learn`.
#
# Finalmente, vamos a comparar los resultados.

# %% [markdown]
# # Generación del dataset
#
# Generamos un dataset sintético, que consta de dos atributos y de un target. Para ello:
#
# - Especificamos el número de ejemplos del dataset a crear.
# - Creamos valores aleatorios para ambos atributos, siguiendo una distribución normal
# - Creamos los valore del target, tomando valores a lo largo de una recta a la que introducimos ruido.

# %%
#Fijamos seed para controlar la aleatoriedad.
np.random.seed(42)

N = 200

# Dos variables explicativas
x1 = np.random.uniform(-3, 3, N)
x2 = np.random.uniform(-3, 3, N)

# Parámetros verdaderos
w1_true = 2.0
w2_true = -1.5
b_true = 4.0

# Generar respuesta con algo de ruido
noise = np.random.normal(0, 1, N)
y = w1_true * x1 + w2_true * x2 + b_true + noise

# %%
## VISUALIZA LOS DATOS
# Usa un eje para cada uno de los atributos

grafico = plt.scatter(x=x1, y=x2)

# Utiliza una escala de color para representar el target.

plt.scatter(x=x1, y=x2, c=y)
plt.colorbar(grafico, label='Target y')

# %% [markdown]
# # 1. Implementación manual

# %% [markdown]
# Comenzamos inicializando los parámetros $w_1$, $w_2$ y $b$, y los hiperparámetros para el descenso del gradiente: la tasa de aprendizaje y el número de epochs.

# %%
# Inicialización de parámetros

w1 = 0.0
w2 = 0.0
b = 0.0
# learning rate
eta = 0.01         
epochs = 1000

# %% [markdown]
# Implementación del descenso del gradiente iterando sobre el número de epochs. Utilizaremos la media del error cuadrático (MSE) en lugar del error cuadrático. ¿Cómo sería la fórmula? En cada epoch:
#
# - Calcula la predicción para los valores de los parámetros dados.
# - Calcula y almacena el error.
# - Pon al día los tres parámetros

# %%
# Para almacenar la pérdida (SE)
loss_history = []


for epoch in range(epochs):
    # Predicciones
    y_pred = (w1 * x1) + (w2 * x2) + b 
    
    # Cálculo del error
    error = y_pred - y
    
    # Calcular pérdida (SE)
    loss = np.mean(error ** 2)
    loss_history.append(loss)

    # Derivadas parciales (gradientes)
    dw1 = (2/N) * np.sum(error * x1)
    dw2 = (2/N) * np.sum(error * x2)
    db = (2/N) * np.sum(error)
    
    # Actualización de parámetros
    w1 = w1 - eta * dw1
    w2 = w2 - eta * dw2
    b = b - eta * db

print(loss_history)
# Out:
# [np.float64(35.32864302022146), np.float64(32.48861707351452), np.float64(29.944197470067657), np.float64(27.661026678951213), np.float64(25.608908518886736), np.float64(23.761297090787068), np.float64(22.094848759813427), np.float64(20.589029397352178), np.float64(19.225770056145898), np.float64(17.98916509561723), np.float64(16.865207513914015), np.float64(15.841556891277428), np.float64(14.907335917292713), np.float64(14.052951972329389), np.float64(13.269940669694359), np.float64(12.550828647314049), np.float64(11.889013232797419), np.float64(11.278656899351933), np.float64(10.714594687350369), np.float64(10.192252991863434), np.float64(9.707578314115178), np.float64(9.256974748030018), np.float64(8.837249124842833), np.float64(8.445562871783228), np.float64(8.079389757441335), np.float64(7.736478798608328), np.float64(7.414821692941303), np.float64(7.11262422029078), np.float64(6.828281124317866), np.float64(6.560354046316235), np.float64(6.307552135992082), np.float64(6.0687150102645475), np.float64(5.842797771736028), np.float64(5.628857834054461), np.float64(5.4260433325672), np.float64(5.233582925992202), np.float64(5.0507768187826665), np.float64(4.876988854853474), np.float64(4.711639551737188), np.float64(4.554199960364543), np.float64(4.404186249800136), np.float64(4.261154928654386), np.float64(4.124698625753643), np.float64(3.9944423621704406), np.float64(3.8700402550610726), np.float64(3.751172601073098), np.float64(3.637543293498211), np.float64(3.528877532967756), np.float64(3.4249197964166664), np.float64(3.325432033362471), np.float64(3.2301920623342335), np.float64(3.1389921436077386), np.float64(3.0516377073154852), np.float64(2.967946218553667), np.float64(2.8877461633475705), np.float64(2.810876141300572), np.float64(2.7371840524740527), np.float64(2.666526367556055), np.float64(2.5987674717013567), np.float64(2.5337790735878296), np.float64(2.4714396722534975), np.float64(2.411634075173255), np.float64(2.3542529618190935), np.float64(2.2991924876365197), np.float64(2.2463539239743846), np.float64(2.195643330036036), np.float64(2.1469712533855905), np.float64(2.100252455952247), np.float64(2.055405662834817), np.float64(2.0123533315242916), np.float64(1.9710214394395262), np.float64(1.9313392879148479), np.float64(1.893239320992576), np.float64(1.8566569575618326), np.float64(1.8215304355506776), np.float64(1.7878006670243816), np.float64(1.7554111031709538), np.float64(1.7243076082680127), np.float64(1.6944383418246105), np.float64(1.6657536481793358), np.float64(1.6382059529133426), np.float64(1.6117496655052128), np.float64(1.5863410877147484), np.float64(1.5619383272360396), np.float64(1.5385012162071492), np.float64(1.515991234205367), np.float64(1.494371435393831), np.float64(1.473606379517912), np.float64(1.4536620664787312), np.float64(1.4345058742368577), np.float64(1.4161064998220598), np.float64(1.3984339032453084), np.float64(1.381459254127316), np.float64(1.365154880874028), np.float64(1.3494942222439084), np.float64(1.3344517811647256), np.float64(1.320003080669108), np.float64(1.3061246218284819), np.float64(1.2927938435743076), np.float64(1.2799890843039021), np.float64(1.267689545175691), np.float64(1.255875255005544), np.float64(1.2445270366820216), np.float64(1.2336264750239563), np.float64(1.2231558860088754), np.float64(1.2130982873053995), np.float64(1.203437370046966), np.float64(1.1941574717881032), np.float64(1.1852435505879937), np.float64(1.1766811601693283), np.float64(1.1684564261034278), np.float64(1.160556022975369), np.float64(1.1529671524853844), np.float64(1.1456775224451647), np.float64(1.138675326629882), np.float64(1.131949225448761), np.float64(1.1254883273989336), np.float64(1.1192821712690666), np.float64(1.1133207090608943), np.float64(1.1075942895983373), np.float64(1.1020936427953252), np.float64(1.0968098645548123), np.float64(1.0917344022727336), np.float64(1.0868590409218633), np.float64(1.082175889691678), np.float64(1.0776773691613768), np.float64(1.073356 ...

# %% [markdown]
# ¿Qué valores de los parámetros has encontrado? ¿Cuál es el valor de la función de coste?

# %%
print("Parámetros aprendidos (GD):")
print(f"w1 = {w1:.3f}, w2 = {w2:.3f}, b = {b:.3f}")
# Out:
# Parámetros aprendidos (GD):
# w1 = 2.002, w2 = -1.530, b = 3.997

# %% [markdown]
# Usando los datos almacenados en el apartado anterior, crea una gráfica con el valor de la función de coste en función de los epochs.

# %%
# Crea la gráfica aquí
plt.plot(loss_history)

# %% [markdown]
# ¿Cómo queda esta gráfica si modificas la tasa de aprendizaje o la inicialización de los parámetros?

# %% [markdown]
# # 2. Implementación con `scikit-learn`

# %% [markdown]
# Repetimos el mismo cálculo usando la implementación de regresión lineal de `scikit-learn`.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Consulta la documentación para comprender la sintaxis.

# %%
# # Expresa los atributos en forma matricial usando numpy
# X = np.column_stack((x1, x2))

# # Instancia el modelo
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# modelo = LinearRegression(n_jobs=1000)


# # Ajusta el modelo
# resultado_modelo = modelo.fit(X_train, y_train)

# # Realiza predicciones sobre el conjunto de entrenamiento
# prediccion = modelo.predict(X_test)

# %%
# Expresa los atributos en forma matricial usando numpy
X = np.column_stack((x1, x2))

# Instancia el modelo
modelo = LinearRegression(n_jobs=1000)


# Ajusta el modelo
resultado_modelo = modelo.fit(X, y)

# Realiza predicciones sobre el conjunto de entrenamiento
prediccion = modelo.predict(X)

# %% [markdown]
# ¿Qué parámetros has obtenido? Consulta la documentación para averiguar cómo extraer estos valores.

# %%
# Imprime aquí los parámetros que has obtenido.
print(modelo.coef_)
# Out:
# [ 2.00163668 -1.53005186]

# %% [markdown]
# # 3. Comparación de los resultados
#
# ¿Difieren mucho los valores de los parámetros que has encontrado?

# %% [markdown]
# Realiza una gráfica que muestre en el eje $x$ el valor real y en el otro el valor predicho manualmente.

# %%
# Muestra la gráfica aquí
plt.scatter(y, y_pred)

# %% [markdown]
# Realiza una gráfica que muestre en el eje $x$ el valor real y en el otro el valor predicho por `scikit-learn`.

# %%
# Muestra la gráfica aquí
plt.scatter(y, prediccion)

# %% [markdown]
# Calcula el error obtenido en ambos casos (MSE).

# %%
# Mostrar MSE final de ambos modelos

manual_mse = mean_squared_error(y, y_pred)

ske_mse = mean_squared_error(y, prediccion)

print(manual_mse, ske_mse)
# Out:
# 0.9680638834948755 0.9680638834948755

# %%
plt.scatter(y, prediccion)
plt.plot(y, y, c="red")
plt.grid()
